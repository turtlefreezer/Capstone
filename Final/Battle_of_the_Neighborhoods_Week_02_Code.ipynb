# %% [markdown]
# # Capstone Project - The Battle of Neighborhoods (Code)

# %% [markdown]
# **Import the Required Libraries**

# %%
# Import libraries
import numpy as np # library to handle data in a vectorized manner
import json # library to handle JSON files
import pandas as pd

from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors

from bs4 import BeautifulSoup

# Import k-means from clustering stage
from sklearn.cluster import KMeans

import folium # map rendering library

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# **Import the Paris District Data**

# %%
# Download the dataset and read it into a pandas dataframe.

# The Arrondissements dataset was downloaded from Paris|DATA:  https://opendata.paris.fr/explore/dataset/arrondissements/table/?dataChart
# Then placed on the GitHub repo for the project.
# https://raw.githubusercontent.com/AR-data-science/Coursera_Capstone/master/Arrondissements_.csv

paris = pd.read_csv('https://raw.githubusercontent.com/AR-data-science/Coursera_Capstone/master/Arrondissements_.csv')
paris
# Out:
#     CAR                 NAME      NSQAR  ...  PERIMETRE  Geometry_X Geometry_Y
# 0     3               Temple  750000003  ...    4519264   48.862872   2.360001
# 1    19      Buttes-Chaumont  750000019  ...   11253182   48.887076   2.384821
# 2    14         Observatoire  750000014  ...   10317483   48.829245   2.326542
# 3    10             Entrepot  750000010  ...    6739375   48.876130   2.360728
# 4    12              Reuilly  750000012  ...   24089666   48.834974   2.421325
# 5    16                Passy  750000016  ...   17416110   48.860392   2.261971
# 6    11           Popincourt  750000011  ...    8282012   48.859059   2.380058
# 7     2               Bourse  750000002  ...    4554104   48.868279   2.342803
# 8     4       Hotel-de-Ville  750000004  ...    5420908   48.854341   2.357630
# 9    17  Batignolles-Monceau  750000017  ...   10775580   48.887327   2.306777
# 10   18    Buttes-Montmartre  750000018  ...    9916464   48.892569   2.348161
# 11    1               Louvre  750000001  ...    6054937   48.862563   2.336443
# 12    5             Pantheon  750000005  ...    6239195   48.844443   2.350715
# 13    7       Palais-Bourbon  750000007  ...    8099425   48.856174   2.312188
# 14   20         Menilmontant  750000020  ...   10704940   48.863461   2.401188
# 15    8               elysee  750000008  ...    7880533   48.872721   2.312554
# 16    9                Opera  750000009  ...    6471588   48.877164   2.337458
# 17   13             Gobelins  750000013  ...   11546547   48.828388   2.362272
# 18   15            Vaugirard  750000015  ...   13678798   48.840085   2.292826
# 19    6           Luxembourg  750000006  ...    6483687   48.849130   2.332898
#
# [20 rows x 11 columns]

# %% [markdown]
# **Exploring, Wrangling and Cleaning the Data**

# %%
# Rename the necessary columns 'Geometry_X and Geometry_Y' etc...

# District : name of the central District for the Arrondissement
# Arrondissement : the Arrondissement or district number which is used to identify it
# Arrondissement_Fr : the descriptive French label for each Arrondissement

paris.rename(columns={'NAME': 'Neighborhood ', 'CAR': 'Arrondissement_Num', 'Geometry_X': 'Latitude', 'Geometry_Y': 'Longitude',  'LAR': 'French_Name'}, inplace=True)
paris
# Out:
#     Arrondissement_Num        Neighborhood   ...   Latitude  Longitude
# 0                    3               Temple  ...  48.862872   2.360001
# 1                   19      Buttes-Chaumont  ...  48.887076   2.384821
# 2                   14         Observatoire  ...  48.829245   2.326542
# 3                   10             Entrepot  ...  48.876130   2.360728
# 4                   12              Reuilly  ...  48.834974   2.421325
# 5                   16                Passy  ...  48.860392   2.261971
# 6                   11           Popincourt  ...  48.859059   2.380058
# 7                    2               Bourse  ...  48.868279   2.342803
# 8                    4       Hotel-de-Ville  ...  48.854341   2.357630
# 9                   17  Batignolles-Monceau  ...  48.887327   2.306777
# 10                  18    Buttes-Montmartre  ...  48.892569   2.348161
# 11                   1               Louvre  ...  48.862563   2.336443
# 12                   5             Pantheon  ...  48.844443   2.350715
# 13                   7       Palais-Bourbon  ...  48.856174   2.312188
# 14                  20         Menilmontant  ...  48.863461   2.401188
# 15                   8               elysee  ...  48.872721   2.312554
# 16                   9                Opera  ...  48.877164   2.337458
# 17                  13             Gobelins  ...  48.828388   2.362272
# 18                  15            Vaugirard  ...  48.840085   2.292826
# 19                   6           Luxembourg  ...  48.849130   2.332898
#
# [20 rows x 11 columns]

# %% [markdown]
# **Clean up the dataset to remove unnecessary columns**

# %%
# Clean up the dataset to remove unnecessary columns.
# Some of the columns are for mapping software - not required here.

paris.drop(['NSQAR','CAR.1','CARINSEE','NSQCO','SURFACE', 'PERIMETRE' ], axis=1, inplace=True)
paris
# Out:
#     Arrondissement_Num        Neighborhood  French_Name   Latitude  Longitude
# 0                    3               Temple   3eme Ardt  48.862872   2.360001
# 1                   19      Buttes-Chaumont  19eme Ardt  48.887076   2.384821
# 2                   14         Observatoire  14eme Ardt  48.829245   2.326542
# 3                   10             Entrepot  10eme Ardt  48.876130   2.360728
# 4                   12              Reuilly  12eme Ardt  48.834974   2.421325
# 5                   16                Passy  16eme Ardt  48.860392   2.261971
# 6                   11           Popincourt  11eme Ardt  48.859059   2.380058
# 7                    2               Bourse   2eme Ardt  48.868279   2.342803
# 8                    4       Hotel-de-Ville   4eme Ardt  48.854341   2.357630
# 9                   17  Batignolles-Monceau  17eme Ardt  48.887327   2.306777
# 10                  18    Buttes-Montmartre  18eme Ardt  48.892569   2.348161
# 11                   1               Louvre    1er Ardt  48.862563   2.336443
# 12                   5             Pantheon   5eme Ardt  48.844443   2.350715
# 13                   7       Palais-Bourbon   7eme Ardt  48.856174   2.312188
# 14                  20         Menilmontant  20eme Ardt  48.863461   2.401188
# 15                   8               elysee   8eme Ardt  48.872721   2.312554
# 16                   9                Opera   9eme Ardt  48.877164   2.337458
# 17                  13             Gobelins  13eme Ardt  48.828388   2.362272
# 18                  15            Vaugirard  15eme Ardt  48.840085   2.292826
# 19                   6           Luxembourg   6eme Ardt  48.849130   2.332898

# %% [markdown]
# **Data Analysis**

# %%
# Check the shape of the dataframe
paris.shape
# Out:
# (20, 5)

# %% [markdown]
# **Use the geopy library to get the latitude and longitude values of Paris**

# %%
# Retrieve the Latitude and Longitude for Paris
from geopy.geocoders import Nominatim 

address = 'Paris'

# Define the user_agent as Paris_explorer
geolocator = Nominatim(user_agent="Paris_explorer")

location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude

print('The geographical coordinates of Paris France are {}, {}.'.format(latitude, longitude))
# Out:
# The geographical coordinates of Paris France are 48.8566969, 2.3514616.

# %% [markdown]
# **Create a map of Paris with districts superimposed**

# %%
# create map of Paris using the above latitude and longitude values
map_paris = folium.Map(location=[latitude, longitude], zoom_start=12)


# add markers to map
for lat, lng, label in zip(paris['Latitude'], paris['Longitude'], paris['French_Name']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=25,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.3,
        parse_html=False).add_to(map_paris)  
    
map_paris
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# **Use the Foursquare API to explore the Arrondissements of Paris (Neighborhoods)**

# %%
CLIENT_ID = 'QEF4SFROUUVOQKNPAFNNRDUW4ACAWSYYG312LM3BKEDDKPIZ' # your Foursquare ID
CLIENT_SECRET = 'CCBFW1WDVTUYDLPFX3SR0QBB5R2UKRYOZ3F1JDJ3PLQMPDRM' # your Foursquare Secret
VERSION = '20180605'

# %% [markdown]
# **Explore the first district in our dataframe to become familiar with the data (use the French descriptive arrondissement name)**

# %%
# Explore the first Neighborhood in our dataframe.
# Get the Neighborhood's French name.

paris.loc[0, 'French_Name']
paris.loc[0, 'French_Name']
# Out:
# '3eme Ardt'

# %% [markdown]
# **Get the neighborhood's latitude and longitude values.**

# %%
neighborhood_latitude = paris.loc[0, 'Latitude'] # Neighborhood latitude value
neighborhood_longitude = paris.loc[0, 'Longitude'] # Neighborhood longitude value

neighborhood_name = paris.loc[0, 'French_Name'] # Neighborhood name

print('Latitude and longitude values of the neighborhood {} are {}, {}.'.format(neighborhood_name, 
                                                               neighborhood_latitude, 
                                                               neighborhood_longitude))
# Out:
# Latitude and longitude values of the neighborhood 3eme Ardt are 48.86287238, 2.3600009859999997.

# %% [markdown]
# **Get the top 100 venues that are in the neighborhood 3eme Ardt within a radius of 500 meters.**

# %%
LIMIT = 100 # limit of number of venues returned by Foursquare API
radius = 500 # define radius

url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neighborhood_latitude, 
    neighborhood_longitude, 
    radius, 
    LIMIT)

# %%
# Send the GET request and examine the resutls

results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5eb3e1af660a9f001fc561d5'},
#  'response': {'groups': [{'items': [{'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4d974096a2c654814aa6d353-0',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1c5941735',
#          'name': 'Sandwich Place',
#          'pluralName': 'Sandwich Places',
#          'primary': True,
#          'shortName': 'Sandwiches'}],
#        'id': '4d974096a2c654814aa6d353',
#        'location': {'address': '57 rue de Bretagne',
#         'cc': 'FR',
#         'city': 'Paris',
#         'country': 'France',
#         'distance': 123,
#         'formattedAddress': ['57 rue de Bretagne', '75003 Paris', 'France'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.86391016055883,
#           'lng': 2.360590696334839}],
#         'lat': 48.86391016055883,
#         'lng': 2.360590696334839,
#         'postalCode': '75003',
#         'state': 'Île-de-France'},
#        'name': 'Mmmozza',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5b546a4a82a750002c940e7f-1',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1c5941735',
#          'name': 'Sandwich Place',
#          'pluralName': 'Sandwich Places',
#          'primary': True,
#          'shortName': 'Sandwiches'}],
#        'id': '5b546a4a82a750002c940e7f',
#        'location': {'address': '26 rue Charlon',
#         'cc': 'FR',
#         'city': 'Paris',
#         'country': 'France',
#         'distance': 153,
#         'formattedAddress': ['26 rue Charlon', '75003 Paris', 'France'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.862369156725826,
#           'lng': 2.361949874504966}],
#         'lat': 48.862369156725826,
#         'lng': 2.361949874504966,
#         'postalCode': '75003',
#         'state': 'Île-de-France'},
#        'name': 'Chez Alain Miam Miam',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4d04b6d6dc45a09314b6ebc6-2',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_cheese_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d11e951735',
#          'name': 'Cheese Shop',
#          'pluralName': 'Cheese Shops',
#          'primary': True,
#          'shortName': 'Cheese Shop'}],
#        'id': '4d04b6d6dc45a09314b6ebc6',
#        'location': {'address': '39 Rue de Bretagne',
#         'cc': 'FR',
#         'city': 'Paris',
#         'country': 'France',
#         'distance': 185,
#         'formattedAddress': ['39 Rue de Bretagne', '75003 Paris', 'France'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.86294724752955,
#           'lng': 2.3625297856770335}],
#         'lat': 48.86294724752955,
#         'lng': 2.3625297856770335,
#         'postalCode': '75003',
#         'state': 'Île-de-France'},
#        'name': 'Fromagerie Jouannault',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b93cba4f964a520155234e3-3',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'primary': True,
#          'shortName': 'Park'}],
#        'id': '4b93cba4f964a520155234e3',
#        'location': {'address': 'Rue du Temple',
#         'cc': 'FR',
#         'city': 'Paris',
#         'country': 'France',
#         'distance': 188,
#         'formattedAddress': ['Rue du Temple', '75003 Paris', 'France'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.86447479436444,
#           'lng': 2.36081600189209}],
#         'lat': 48.86447479436444,
#         'lng': 2.36081600189209,
#         'postalCode': '75003',
#         'state': 'Île-de-France'},
#        'name': 'Square du Temple',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b75734cf964a5202c0d2ee3-4',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_farmersmarket_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1fa941735',
#          'name': 'Farmers Market',
#          'pluralName': 'Farmers Markets',
#          'primary': True,
#          'shortName': "Farmer's Market"}],
#        'id': '4b75734cf964a5202c0d2ee3',
#        'location': {'address': '39 rue de Bretagne',
#         'cc': 'FR',
#         'city': 'Paris',
#         'country': 'France',
#         'distance': 146,
#         'formattedAddress': ['39 rue de Bretagne', '75003 Paris', 'France'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.862805577255905,
#           'lng': 2.3619961738586426}],
#         'lat': 48.862805577255905,
#         'lng': 2.3619961738586426,
#         'postalCode': '75003',
#         'state': 'Île-de-France'},
#        'name': 'Marché des Enfants Rouges',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-526d0c5511d275f7419369d4-5',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1c5941735',
#          'name': 'Sandwich Place',
#          'pluralName': 'Sandwich Places',
#          'primary': True,
#          'shortName': 'Sandwiches'}],
#        'id': '526d0c5511d275f7419369d4',
#        'location': {'address': '39 rue de Bretagne',
#         'cc': 'FR',
#         'city': 'Paris',
#         'country': 'France',
#         'distance': 151,
#         'formattedAddress': ['39 rue de Bretagne', '75003 Paris', 'France'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.86278066936393,
#           'lng': 2.362063870044378}],
#         'lat': 48.86278066936393,
#         'lng': 2.362063870044378,
#         'postalCode': '75003',
#         'state': 'Île-de-France'},
#        'name': 'Chez Alain Miam Miam',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-531b51a8498e6c00a66f0606-6',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'id': '55a59bace4b013909087cb18',
#          'name': 'Okonomiyaki Restaurant',
#          'pluralName': 'Okonomiyaki Restaurants',
#          'primary': True,
#          'shortName': 'Okonomiyaki'}],
#        'id': '531b51a8498e6c00a66f0606',
#        'location': {'address': '11 rue Charlot',
#         'cc': 'FR',
#         'city': 'Paris',
#         'country': 'France',
#         'distance': 170,
#         'formattedAddress': ['11 rue Charlot', '75003 Paris', 'France'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.8614528716404,
#           'lng': 2.360878892024778}],
#         'lat': 48.8614528716404,
#         'lng': 2.360878892024778,
#         'postalCode': '75003',
#         'state': 'Île-de-France'},
#        'name': 'Okomusu',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-513b20f4e4b017813c20e275-7',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'primary': True,
#          'shortName': 'Burgers'}],
#        'id': '513b20f4e4b017813c20e275',
#        'location': {'address': '39 rue de Bretagne',
#         'cc': 'FR',
#         'city': 'Paris',
#         'country': 'France',
#         'distance': 151,
#         'formattedAddress': ['39 rue de Bretagne', '75003 Paris', 'France'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.862831267361834,
#           'lng': 2.362072655802718}],
#         'lat': 48.862831267361834,
#         'lng': 2.362072655802718,
#         'postalCode': '75003',
#         'state': 'Île-de-France'},
#        'name': 'Le Burger Fermier des Enfants Rouges',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4c7d0a8948c6236ac1406311-8',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'primary': True,
#          'shortName': 'Hotel'}],
#        'id': '4c7d0a8948c6236ac1406311',
#        'location': {'address': '11 rue des Gravilliers',
#         'cc': 'FR',
#         'city': 'Paris',
#         'country': 'France',
#         'distance': 203,
#         'formattedAddress': ['11 rue des Gravilliers',
#          '75003 Paris',
#          'France'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.86349582021051,
#           'lng': 2.3573948716806172}],
#         'lat': 48.86349582021051,
#         'lng': 2.3573948716806172,
#         'postalCode': '75003',
#         'state': 'Île-de-France'},
#        'name': 'Hôtel Jules & Jim',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-542328dc498ecb84a246bd46-9',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d111941735',
#          'name': 'Japanese Restaurant',
#          'pluralName': 'Japanese Restaurants',
#          'primary': True,
#          'shortName': 'Japanese'}],
#        'id': '542328dc498ecb84a246bd46',
#        'location': {'address': '13 rue de Saintonge',
#         'cc': 'FR',
#         'city': 'Paris',
#         'country': 'France',
#         'distance': 218,
#         'formattedAddress': ['13 rue de Saintonge', '75003 Paris', 'France'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.86151090488514,
#           'lng': 2.3621459089408225}],
#         'lat': 48.86151090488514,
#         'lng': 2.3621459089408225,
#         'postalCode': '75003',
#         'state': 'Île-de-France'},
#        'name': 'SoMa',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-52505ced11d2d39c3cd942a6-10',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/winery_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d123941735',
#          'name': 'Wine Bar',
#          'pluralName': 'Wine Bars',
#          'primary': True,
#          'shortName': 'Wine Bar'}],
#        'id': '52505ced11d2d39c3cd942a6',
#        'location': {'address': '9 rue de Beauce',
#         'cc': 'FR',
#         'city': 'Paris',
#         'country': 'France',
#         'distance': 93,
#         'formattedAddress': ['9 rue de Beauce', '75003 Paris', 'France'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.863012925486814,
#           'lng': 2.3612595453403116}],
#         'lat': 48.863012925486814,
#         'lng': 2.3612595453403116,
#         'postalCode': '75003',
#         'state': 'Île-de-France'},
#        'name': 'Les Enfants Rouges',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-54e8b123498ece133b1d6594-11',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1d0941735',
#          'name': 'Dessert Shop',
#          'pluralName': 'Dessert Shops',
#          'primary': True,
#          'shortName': 'Desserts'}],
#        'id': '54e8b123498ece133b1d6594',
#        'location': {'address': '57 rue de Bretagne',
#         'cc': 'FR',
#         'city': 'Paris',
#         'country': 'France',
#         'distance': 131,
#         'formattedAddress': ['57 rue de Bretagne', '75003 Paris', 'France'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.86395594363815,
#           'lng': 2.360725075150604}],
#         'lat': 48.86395594363815,
#         'lng': 2.360725075150604,
#         'postalCode': '75003',
#         'state': 'Île-de-France'},
#        'name': 'Bontemps',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4bbf1e2c30c99c74319f5411-12',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d111941735',
#          'name': 'Japanese Restaurant',
#          'pluralName': 'Japanese Restaurants',
#          'primary': True,
#          'shortName': 'Japanese'}],
#        'id': '4bbf1e2c30c99c74319f5411',
#        'location': {'address': '39 rue de Bretagne',
#         'cc': 'FR',
#         'city': 'Paris',
#         'country': 'France',
#         'distance': 157,
#         'formattedAddress': ['39 rue de Bretagne', '75003 Paris', 'France'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.862733763586455,
#           'lng': 2.362135982749459}],
#         'lat': 48.862733763586455,
#         'lng': 2.362135982749459,
#         'postalCode': '75003',
#         'state': 'Île-de-France'},
#        'name': 'Chez Taeko',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4f4e96eae4b0a99a78161d9e-13',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_bar_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1d5941735',
#          'name': 'Hotel Bar',
#          'pluralName': 'Hotel Bars',
#          'primary': True,
#          'shortName': 'Hotel Bar'}],
#        'id': '4f4e96eae4b0a99a78161d9e',
#        'location': {'address': '11 rue des Gravilliers',
#         'cc': 'FR',
#         'city': 'Paris',
#         'country': 'France',
#         'distance': 201,
#         'formattedAddress': ['11 rue des Gravilliers',
#          '75003 Paris',
#          'France'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.86346264663714,
#           'lng': 2.357393198185953}],
#         'lat': 48.86346264663714,
#         'lng': 2.357393198185953,
#         'postalCode': '75003',
#         'state': 'Île-de-France'},
#        'name': "Bar de l'Hôtel Jules et Jim",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-551ab159498e0f0eb50a5a1f-14',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'primary': True,
#          'shortName': 'Burgers'}],
#        'id': '551ab159498e0f0eb50a5a1f',
#        'location': {'address': '1 rue Perrée',
#         'cc': 'FR',
#         'city': 'Paris',
#         'country': 'France',
#         'crossStreet': 'rue de Picardie',
#         'distance': 222,
#         'formattedAddress': ['1 rue Perrée (rue de Picardie)',
#          '75003 Paris',
#          'France'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.86384310987126,
#           'lng': 2.3626613616943355}],
#         'lat': 48.86384310987126,
#         'lng': 2.3626613616943355,
#         'postalCode': '75003',
#         'state': 'Île-de-France'},
#        'name': 'Paris New York',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-583025d07ff1e43c19cd8599-15',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'primary': True,
#          'shortName': 'Italian'}],
#        'id': '583025d07ff1e43c19cd8599',
#        'location': {'address': '30 rue Debelleyme',
#         'cc': 'FR',
#         'city': 'Paris',
#         'country': 'France',
#         'distance': 275,
#         'formattedAddress': ['30 rue Debelleyme', '75003 Paris', 'France'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.86206260694734,
#           'lng': 2.363556952325989}],
#         'lat': 48.86206260694734,
#         'lng': 2.363556952325989,
#         'postalCode': '75003',
#         'state': 'Île-de-France'},
#        'name': 'Biglove Caffè',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-53724c11498e6b2e00253345-16',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/tearoom_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1dc931735',
#          'name': 'Tea Room',
#          'pluralName': 'Tea Rooms',
#          'primary': True,
#          'shortName': 'Tea Room'}],
#        'id': '53724c11498e6b2e00253345',
#        'location': {'address': '12 rue Dupetit-Thouars',
#         'cc': 'FR',
#         'city': 'Paris',
#         'country': 'France',
#         'distance': 299,
#         'formattedAddress': ['12 rue Dupetit-Thouars',
#          '75003 Paris',
#          'France'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.86522055747545,
#           'lng': 2.3619898784439703}],
#         'lat': 48.86522055747545,
#         'lng': 2.3619898784439703,
#         'postalCode': '75003',
#         'state': 'Île-de-France'},
#        'name': 'Lily of the Valley',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-501ab9cfe4b089ae3961a041-17',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1ce941735',
#          'name': 'Seafood Restaurant',
#          'pluralName': 'Seafood Restaurants',
#          'primary': True,
#          'shortName': 'Seafood'}],
#        'id': '501ab9cfe4b089ae3961a041',
#        'location': {'address': '4 rue de la Corderie',
#         'cc': 'FR',
#         'city': 'Paris',
#         'country': 'France',
#         'distance': 314,
#         'formattedAddress': ['4 rue de la Corderie', '75004 Paris', 'France'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.864666,
#           'lng': 2.363317}],
#         'lat': 48.864666,
#         'lng': 2.363317,
#         'postalCode': '75004',
#         'state': 'Île-de-France'},
#        'name': "L'Îlot",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4d77b39caf63cbff3997be0f-18',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d11e941735',
#          'name': 'Cocktail Bar',
#          'pluralName': 'Cocktail Bars',
#          'primary': True,
#          'shortName': 'Cocktail'}],
#        'id': '4d77b39caf63cbff3997be0f',
#        'location': {'address': '56 rue de Saintonge',
#         'cc': 'FR',
#         'city': 'Paris',
#         'country': 'France',
#         'distance': 297,
#         'formattedAddress': ['56 rue de Saintonge', '75003 Paris', 'France'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.86303212989039,
#           'lng': 2.3640589318953125}],
#         'lat': 48.86303212989039,
#         'lng': 2.3640589318953125,
#         'postalCode': '75003',
#         'state': 'Île-de-France'},
#        'name': 'Candelaria',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b4b9831f964a5205fa126e3-19',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d14a941735',
#          'name': 'Vietnamese Restaurant',
#          'pluralName': 'Vietnamese Restaurants',
#          'primary': True,
#          'shortName': 'Vietnamese'}],
#        'id': '4b4b9831f964a5205fa126e3',
#        'location': {'address': '3 rue Volta',
#         'cc': 'FR',
#         'city': 'Paris',
#         'country': 'France',
#         'distance': 305,
#         'formattedAddress': ['3 rue Volta', '75003 Paris', 'France'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.86470055655422,
#           'lng': 2.3568883433485377}],
#         'lat': 48.86470055655422,
#         'lng': 2.3568883433485377,
#         'postalCode': '75003',
#         'state': 'Île-de-France'},
#        'name': 'Taing Song-Heng',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b61e549f964a520cd292ae3-20',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bookstore_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d114951735',
#          'name': 'Bookstore',
#          'pluralName': 'Bookstores',
#          'primary': True,
#          'shortName': 'Bookstore'}],
#        'id': '4b61e549f964a520cd292ae3',
#        'location': {'address': '20 rue Dupetit-Thouars',
#         'cc': 'FR',
#         'city': 'Paris',
#         'country': 'France',
#         'distance': 332,
#         'formattedAddress': ['20 rue Dupetit-Thouars',
#          '75003 Paris',
#          'France'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.86574636171658,
#           'lng': 2.361235606513219}],
#         'lat': 48.86574636171658,
#         'lng': 2.361235606513219,
#         'postalCode': '75003',
#         'state': 'Île-de-France'},
#        'name': '0fr.',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b700b25f964a5209d042de3-21',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'primary': True,
#          'shortName': 'Café'}],
#        'id': '4b700b25f964a5209d042de3',
#        'location': {'address': '126 rue du Temple',
#         'cc': 'FR',
#         'city': 'Paris',
#         'country': 'France',
#         'distance': 136,
#         'formattedAddress': ['126 rue du Temple', '75003 Paris', 'France'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.86337459584866,
#           'lng': 2.3582987922392618}],
#         'lat': 48.86337459584866,
#         'lng': 2.3582987922392618,
#         'postalCode': '75003',
#         'state': 'Île-de-France'},
#        'name': 'Le Roi de Pique',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b68a117f964a520c8832be3-22',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/winery_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d123941735',
#          'name': 'Wine Bar',
#          'pluralName': 'Wine Bars',
#          'primary': True,
#          'shortName': 'Wine Bar'}],
#        'id': '4b68a117f964a520c8832be3',
#        'location': {'address': '6 rue Charles-François Dupuis',
#         'cc': 'FR',
#         'city': 'Paris',
#         'country': 'France',
#         'crossStreet': 'Rue de la Corderie',
#         'distance': 344,
#         'formattedAddress': ['6 rue Charles-François Dupuis (Rue de la Corderie)',
#          '75003 Paris',
#          'France'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.86516646209463,
#           'lng': 2.363154888153076}],
#         'lat': 48.86516646209463,
#         'lng': 2.363154888153076,
#         'postalCode': '75003',
#         'state': 'Île-de-France'},
#        'name': 'Le Barav',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4c4dbdf29efabe9af5840169-23',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d103951735',
#          'name': 'Clothing Store',
#          'pluralName': 'Clothing Stores',
#          'primary': True,
#          'shortName': 'Apparel'}],
#        'id': '4c4dbdf29efabe9af5840169',
#        'location': {'address': '128 rue Vieille du Temple',
#         'cc': 'FR',
#         'city': 'Paris',
#         'country': 'France',
#         'distance': 324,
#         'formattedAddress': ['128 rue Vieille du Temple',
#          '75003 Paris',
#          'France'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.86179145989662,
#           'lng': 2.3641142537557283}],
#         'lat': 48.86179145989662,
#         'lng': 2.3641142537557283,
#         'postalCode': '75003',
#         'state': 'Île-de-France'},
#        'name': 'French Trotters',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4e0754b21838eb15af00b5c5-24',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/garden_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d15a941735',
#          'name': 'Garden',
#          'pluralName': 'Gardens',
#          'primary': True,
#          'shortName': 'Garden'}],
#        'id': '4e0754b21838eb15af00b5c5',
#        'location': {'address': '87 rue Vieille-du-Temple',
#         'cc': 'FR',
#         'city': 'Paris',
#         'country': 'France',
#         'distance': 342,
#         'formattedAddress': ['87 rue Vieille-du-Temple',
#          '75003 Paris',
#          'France'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.85992931145873,
#           'lng': 2.358659505844116}],
#         'lat': 48.85992931145873,
#         'lng': 2.358659505844116,
#         'postalCode': '75003',
#         'state': 'Île-de-France'},
#        'name': 'Jardin des Archives Nationales',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5a8c1166e1f22874f4fc9714-25',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bubble_',
#           'suffix': '.png'},
#          'id': '52e81612bcbc57f1066b7a0c',
#          'name': 'Bubble Tea Shop',
#          'pluralName': 'Bubble Tea Shops',
#          'primary': True,
#          'shortName': 'Bubble Tea'}],
#        'id': '5a8c1166e1f22874f4fc9714',
#        'location': {'address': '19 rue de Montmorency',
#         'cc': 'FR',
#         'city': 'Paris',
#         'country': 'France',
#         'distance': 361,
#         'formattedAddress': ['19 rue de Montmorency', '75003 Paris', 'France'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.86307722773456,
#           'lng': 2.355072994853153}],
#         'lat': 48.86307722773456,
#         'lng': 2.355072994853153,
#         'neighborhood': 'Rambuteau',
#         'postalCode': '75003',
#         'state': 'Île-de-France'},
#        'name': 'Laïzé 來座 (Laïzé)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-576e911f498ee478d1636f11-26',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'primary': True,
#          'shortName': 'Coffee Shop'}],
#        'id': '576e911f498ee478d1636f11',
#        'location': {'address': '106 rue de Turenne',
#         'cc': 'FR',
#         'city': 'Paris',
#         'country': 'France',
#         'distance': 349,
#         'formattedAddress': ['106 rue de Turenne', '75003 Paris', 'France'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.862612,
#           'lng': 2.364752}],
#         'lat': 48.862612,
#         'lng': 2.364752,
#         'postalCode': '75003',
#         'state': 'Île-de-France'},
#        'name': 'Fringe',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '215660933'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4dcad848c65bebb82f42d5c5-27',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d10c941735',
#          'name': 'French Restaurant',
#          'pluralName': 'French Restaurants',
#          'primary': True,
#          'shortName': 'French'}],
#        'id': '4dcad848c65bebb82f42d5c5',
#        'location': {'address': '5 rue Charles-François Dupuis',
#         'cc': 'FR',
#         'city': 'Paris',
#         'country': 'France',
#         'distance': 353,
#         'formattedAddress': ['5 rue Charles-François Dupuis',
#          '75003 Paris',
#          'France'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.86524712816095,
#           'lng': 2.363203378474113}],
#         'lat': 48.86524712816095,
#         'lng': 2.363203378474113,
#         'postalCode': '75003',
#         'state': 'Île-de-France'},
#        'name': "L'Aller Retour",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4c0aa0eb009a0f47adbee9bf-28',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1e2931735',
#          'name': 'Art Gallery',
#          'pluralName': 'Art Galleries',
#          'primary': True,
#          'shortName': 'Art Gallery'}],
#        'id': '4c0aa0eb009a0f47adbee9bf',
#        'location': {'address': '7 rue Debelleyme',
#         'cc': 'FR',
#         'city': 'Paris',
#         'country': 'France',
#         'distance': 363,
#         'formattedAddress': ['7 rue Debelleyme', '75003 Paris', 'France'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.86058151476433,
#           'lng': 2.3635389810078777}],
#         'lat': 48.86058151476433,
#         'lng': 2.3635389810078777,
#         'postalCode': '75003',
#         'state': 'Île-de-France'},
#        'name': 'Galerie Thaddaeus Ropac',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4af5aeaaf964a5203cfb21e3-29',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'id': '52f2ab2ebcbc57f1066b8b46',
#          'name': 'Supermarket',
#          'pluralName': 'Supermarkets',
#          'primary': True,
#          'shortName': 'Supermarket'}],
#        'id': '4af5aeaaf964a5203cfb21e3',
#        'location': {'address': '164 rue du Temple',
#         'cc': 'FR',
#         'city': 'Paris',
#         'country': 'France',
#         'distance': 382,
#         'formattedAddress': ['164 rue du Temple', '75003 Paris', 'France'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.866149910688705,
#           'lng': 2.3615482449531555}],
#         'lat': 48.866149910688705,
#         'lng': 2.3615482449531555,
#         'postalCode': '75003',
#         'state': 'Île-de-France'},
#        'name': 'Monoprix',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '587245043'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5083046de4b01d45a22621c0-30',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'primary': True,
#          'shortName': 'Italian'}],
#        'id': '5083046de4b01d45a22621c0',
#        'location': {'address': '70 rue de Turbigo',
#         'cc': 'FR',
#         'city': 'Paris',
#         'country': 'France',
#         'distance': 360,
#         'formattedAddress': ['70 rue de Turbigo', '75003 Paris', 'France'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.866098081070305,
#           'lng': 2.3595499992370605}],
#         'lat': 48.866098081070305,
#         'lng': 2.3595499992370605,
#         'postalCode': '75003',
#         'state': 'Île-de-France'},
#        'name': 'La Massara',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '44986821'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4adcda0ef964a5204f3521e3-31',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_art_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d18f941735',
#          'name': 'Art Museum',
#          'pluralName': 'Art Museums',
#          'primary': True,
#          'shortName': 'Art Museum'}],
#        'id': '4adcda0ef964a5204f3521e3',
#        'location': {'address': '5 rue de Thorigny',
#         'cc': 'FR',
#         'city': 'Paris',
#         'country': 'France',
#         'crossStreet': 'Hôtel Salé',
#         'distance': 370,
#         'formattedAddress': ['5 rue de Thorigny (Hôtel Salé)',
#          '75003 Paris',
#          'France'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.8599046066194,
#           'lng': 2.362285852432251}],
#         'lat': 48.8599046066194,
#         'lng': 2.362285852432251,
#         'postalCode': '75003',
#         'state': 'Île-de-France'},
#        'name': 'Musée Picasso',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5644be86498e2c035cd70926-32',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'id': '50aa9e744b90af0d42d5de0e',
#          'name': 'Health Food Store',
#          'pluralName': 'Health Food Stores',
#          'primary': True,
#          'shortName': 'Health Food Store'}],
#        'id': '5644be86498e2c035cd70926',
#        'location': {'address': '8 rue des Quatre-Fils',
#         'cc': 'FR',
#         'city': 'Paris',
#         'country': 'France',
#         'distance': 302,
#         'formattedAddress': ['8 rue des Quatre-Fils', '75003 Paris', 'France'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.860179275688644,
#           'lng': 2.360499405336424}],
#         'lat': 48.860179275688644,
#         'lng': 2.360499405336424,
#         'postalCode': '75003',
#         'state': 'Île-de-France'},
#        'name': "Bien l'Épicerie",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-58946a922a198259b0ea45a0-33',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/juicebar_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d112941735',
#          'name': 'Juice Bar',
#          'pluralName': 'Juice Bars',
#          'primary': True,
#          'shortName': 'Juice Bar'}],
#        'id': '58946a922a198259b0ea45a0',
#        'location': {'address': '26 rue Chapon',
#         'cc': 'FR',
#         'city': 'Paris',
#         'country': 'France',
#         'distance': 339,
#         'formattedAddress': ['26 rue Chapon', '75003 Paris', 'France'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.863614,
#           'lng': 2.355505}],
#         'lat': 48.863614,
#         'lng': 2.355505,
#         'postalCode': '75003',
#         'state': 'Île-de-France'},
#        'name': 'Love Juice Bar',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5116b70ce4b0d096ad258d22-34',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d11e941735',
#          'name': 'Cocktail Bar',
#          'pluralName': 'Cocktail Bars',
#          'primary': True,
#          'shortName': 'Cocktail'}],
#        'id': '5116b70ce4b0d096ad258d22',
#        'location': {'address': '1 rue Commines',
#         'cc': 'FR',
#         'city': 'Paris',
#         'country': 'France',
#         'crossStreet': 'Rue Froissart',
#         'distance': 387,
#         'formattedAddress': ['1 rue Commines (Rue Froissart)',
#          '75004 Paris',
#          'France'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.86174155463238,
#           'lng': 2.3650123178958893}],
#         'lat': 48.86174155463238,
#         'lng': 2.3650123178958893,
#         'postalCode': '75004',
#         'state': 'Île-de-France'},
#        'name': 'Le Mary Céleste',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4af77f16f964a520970922e3-35',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'id': '52e81612bcbc57f1066b79f1',
#          'name': 'Bistro',
#          'pluralName': 'Bistros',
#          'primary': True,
#          'shortName': 'Bistro'}],
#        'id': '4af77f16f964a520970922e3',
#        'location': {'address': '78 rue Vieille du Temple',
#         'cc': 'FR',
#         'city': 'Paris',
#         'country': 'France',
#         'distance': 325,
#         'formattedAddress': ['78 rue Vieille du Temple',
#          '75003 Paris',
#          'France'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.85998512078513,
#           'lng': 2.3607351500162}],
#         'lat': 48.85998512078513,
#         'lng': 2.3607351500162,
#         'neighborhood': 'Marais',
#         'postalCode': '75003',
#         'state': 'Île-de-France'},
#        'name': 'La Perle',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-55cb1496498e413bc3ada4e3-36',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'primary': True,
#          'shortName': 'Bakery'}],
#        'id': '55cb1496498e413bc3ada4e3',
#        'location': {'address': '42 rue Réaumur',
#         'cc': 'FR',
#         'city': 'Paris',
#         'country': 'France',
#         'distance': 374,
#         'formattedAddress': ['42 rue Réaumur', '75003 Paris', 'France'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.865431512731405,
#           'lng': 2.3566765741438243}],
#         'lat': 48.865431512731405,
#         'lng': 2.3566765741438243,
#         'postalCode': '75003',
#         'state': 'Île-de-France'},
#        'name': 'Ernest & Valentin',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4e79bf50152015fb25d33337-37',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/beauty_cosmetic_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d10c951735',
#          'name': 'Cosmetics Shop',
#          'pluralName': 'Cosmetics Shops',
#          'primary': True,
#          'shortName': 'Cosmetics'}],
#        'id': '4e79bf50152015fb25d33337',
#        'location': {'address': '64 rue Vieille du Temple',
#         'cc': 'FR',
#         'city': 'Paris',
#         'country': 'France',
#         'distance': 411,
#         'formattedAddress': ['64 rue Vieille du Temple',
#          '75003 Paris',
#          'France'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.859189513902145,
#           'lng': 2.359553834194295}],
#         'lat': 48.859189513902145,
#         'lng': 2.359553834194295,
#         'postalCode': '75003',
#         'state': 'Île-de-France'},
#        'name': 'Aesop',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4bbb21da935e9521aac82890-38',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/garden_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d15a941735',
#          'name': 'Garden',
#          'pluralName': 'Gardens',
#          'primary': True,
#          'shortName': 'Garden'}],
#        'id': '4bbb21da935e9521aac82890',
#        'location': {'address': 'Impasse Berthaud',
#         'cc': 'FR',
#         'city': 'Paris',
#         'country': 'France',
#         'distance': 390,
#         'formattedAddress': ['Impasse Berthaud', '75003 Paris', 'France'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.86169546412832,
#           'lng': 2.3549842888314743}],
#         'lat': 48.86169546412832,
#         'lng': 2.3549842888314743,
#         'postalCode': '75003',
#         'state': 'Île-de-France'},
#        'name': 'Jardin Anne Frank',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-57288bcc498ef4036039f14e-39',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'primary': True,
#          'shortName': 'Italian'}],
#        'id': '57288bcc498ef4036039f14e',
#        'location': {'address': '1 Rue Borda',
#         'cc': 'FR',
#         'country': 'France',
#         'distance': 399,
#         'formattedAddress': ['1 Rue Borda', '75002', 'France'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.86609262667821,
#           'lng': 2.3575964574327406}],
#         'lat': 48.86609262667821,
#         'lng': 2.3575964574327406,
#         'postalCode': '75002'},
#        'name': 'La Rusidda',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-50042918e4b00846b850b24d-40',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_gourmet_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1f5941735',
#          'name': 'Gourmet Shop',
#          'pluralName': 'Gourmet Shops',
#          'primary': True,
#          'shortName': 'Gourmet'}],
#        'id': '50042918e4b00846b850b24d',
#        'location': {'address': '60 rue Vieille du Temple',
#         'cc': 'FR',
#         'city': 'Paris',
#         'country': 'France',
#         'distance': 437,
#         'formattedAddress': ['60 rue Vieille du Temple',
#          '75003 Paris',
#          'France'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.8589788859021,
#           'lng': 2.3592295526222755}],
#         'lat': 48.8589788859021,
#         'lng': 2.3592295526222755,
#         'postalCode': '75003',
#         'state': 'Île-de-France'},
#        'name': 'La Chambre aux Confitures',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5149c2738aca0ead6a573ce5-41',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
# ...
#        'location': {'address': '12 rue Notre-Dame de Nazareth',
#         'cc': 'FR',
#         'city': 'Paris',
#         'country': 'France',
#         'distance': 480,
#         'formattedAddress': ['12 rue Notre-Dame de Nazareth',
#          '75003 Paris',
#          'France'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.86711966603273,
#           'lng': 2.36118346452713}],
#         'lat': 48.86711966603273,
#         'lng': 2.36118346452713,
#         'postalCode': '75003',
#         'state': 'Île-de-France'},
#        'name': 'Trois Fois Vin',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-566ade3d498e2d313f7273ff-71',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d146941735',
#          'name': 'Deli / Bodega',
#          'pluralName': 'Delis / Bodegas',
#          'primary': True,
#          'shortName': 'Deli / Bodega'}],
#        'id': '566ade3d498e2d313f7273ff',
#        'location': {'cc': 'FR',
#         'country': 'France',
#         'distance': 428,
#         'formattedAddress': ['France'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.86335,
#           'lng': 2.354189}],
#         'lat': 48.86335,
#         'lng': 2.354189},
#        'name': 'Les Épiciers',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4adcda08f964a520bb3321e3-72',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d11e941735',
#          'name': 'Cocktail Bar',
#          'pluralName': 'Cocktail Bars',
#          'primary': True,
#          'shortName': 'Cocktail'}],
#        'id': '4adcda08f964a520bb3321e3',
#        'location': {'address': '69 rue des Gravilliers',
#         'cc': 'FR',
#         'city': 'Paris',
#         'country': 'France',
#         'distance': 463,
#         'formattedAddress': ['69 rue des Gravilliers',
#          '75003 Paris',
#          'France'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.864551443793395,
#           'lng': 2.354207084327789}],
#         'lat': 48.864551443793395,
#         'lng': 2.354207084327789,
#         'postalCode': '75003',
#         'state': 'Île-de-France'},
#        'name': 'Andy Wahloo',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-58173bd438fa1979d91e639c-73',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d111941735',
#          'name': 'Japanese Restaurant',
#          'pluralName': 'Japanese Restaurants',
#          'primary': True,
#          'shortName': 'Japanese'}],
#        'id': '58173bd438fa1979d91e639c',
#        'location': {'address': '63 Rue des Gravilliers',
#         'cc': 'FR',
#         'city': 'Paris',
#         'country': 'France',
#         'distance': 431,
#         'formattedAddress': ['63 Rue des Gravilliers',
#          '75003 Paris',
#          'France'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.864398,
#           'lng': 2.354591}],
#         'lat': 48.864398,
#         'lng': 2.354591,
#         'postalCode': '75003',
#         'state': 'Île-de-France'},
#        'name': 'Koko Cantine',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b0ff071f964a520806623e3-74',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cupcakes_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1bc941735',
#          'name': 'Cupcake Shop',
#          'pluralName': 'Cupcake Shops',
#          'primary': True,
#          'shortName': 'Cupcakes'}],
#        'id': '4b0ff071f964a520806623e3',
#        'location': {'address': '23 rue Rambuteau',
#         'cc': 'FR',
#         'city': 'Paris',
#         'country': 'France',
#         'distance': 452,
#         'formattedAddress': ['23 rue Rambuteau', '75004 Paris', 'France'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.860826455756644,
#           'lng': 2.354666493379683}],
#         'lat': 48.860826455756644,
#         'lng': 2.354666493379683,
#         'postalCode': '75004',
#         'state': 'Île-de-France'},
#        'name': 'Berko Original',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4adcda13f964a520ae3621e3-75',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d10c941735',
#          'name': 'French Restaurant',
#          'pluralName': 'French Restaurants',
#          'primary': True,
#          'shortName': 'French'}],
#        'id': '4adcda13f964a520ae3621e3',
#        'location': {'address': '32 rue du Vertbois',
#         'cc': 'FR',
#         'city': 'Paris',
#         'country': 'France',
#         'distance': 483,
#         'formattedAddress': ['32 rue du Vertbois', '75003 Paris', 'France'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.86702338016517,
#           'lng': 2.358080299757337}],
#         'lat': 48.86702338016517,
#         'lng': 2.358080299757337,
#         'postalCode': '75003',
#         'state': 'Île-de-France'},
#        'name': "L'Ami Louis",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-59d9f6df0a464d2a7886b524-76',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'primary': True,
#          'shortName': 'Bakery'}],
#        'id': '59d9f6df0a464d2a7886b524',
#        'location': {'address': '17 rue du Vertbois',
#         'cc': 'FR',
#         'city': 'Paris',
#         'country': 'France',
#         'distance': 473,
#         'formattedAddress': ['17 rue du Vertbois', '75003 Paris', 'France'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.866952,
#           'lng': 2.358172}],
#         'lat': 48.866952,
#         'lng': 2.358172,
#         'postalCode': '75003',
#         'state': 'Île-de-France'},
#        'name': 'Le Petit Parisien',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5605c782498e2ffecd86f97b-77',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d10c941735',
#          'name': 'French Restaurant',
#          'pluralName': 'French Restaurants',
#          'primary': True,
#          'shortName': 'French'}],
#        'id': '5605c782498e2ffecd86f97b',
#        'location': {'address': '46 rue de Montmorency',
#         'cc': 'FR',
#         'city': 'Paris',
#         'country': 'France',
#         'distance': 467,
#         'formattedAddress': ['46 rue de Montmorency', '75003 Paris', 'France'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.863406405468076,
#           'lng': 2.3536747147872727}],
#         'lat': 48.863406405468076,
#         'lng': 2.3536747147872727,
#         'neighborhood': 'Le Mar',
#         'postalCode': '75003',
#         'state': 'Île-de-France'},
#        'name': 'Le MaZenay',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '180549891'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4adcda11f964a520e53521e3-78',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#           'suffix': '.png'},
#          'id': '57558b36e4b065ecebd306b8',
#          'name': 'Auvergne Restaurant',
#          'pluralName': 'Auvergne Restaurants',
#          'primary': True,
#          'shortName': 'Auvergne'}],
#        'id': '4adcda11f964a520e53521e3',
#        'location': {'address': '22 rue du Grenier Saint-Lazare',
#         'cc': 'FR',
#         'city': 'Paris',
#         'country': 'France',
#         'distance': 499,
#         'formattedAddress': ['22 rue du Grenier Saint-Lazare',
#          '75003 Paris',
#          'France'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.86294673006787,
#           'lng': 2.35318236557205}],
#         'lat': 48.86294673006787,
#         'lng': 2.35318236557205,
#         'postalCode': '75003',
#         'state': 'Île-de-France'},
#        'name': "Ambassade d'Auvergne",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b595440f964a5203d8528e3-79',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d10c941735',
#          'name': 'French Restaurant',
#          'pluralName': 'French Restaurants',
#          'primary': True,
#          'shortName': 'French'}],
#        'id': '4b595440f964a5203d8528e3',
#        'location': {'address': '40 Clos des Blancs-Manteaux',
#         'cc': 'FR',
#         'city': 'Paris',
#         'country': 'France',
#         'distance': 500,
#         'formattedAddress': ['40 Clos des Blancs-Manteaux',
#          '75004 Paris',
#          'France'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.8597407868756,
#           'lng': 2.3550904121584857}],
#         'lat': 48.8597407868756,
#         'lng': 2.3550904121584857,
#         'postalCode': '75004',
#         'state': 'Île-de-France'},
#        'name': 'Claude Colliot',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-50f9a020e4b05cb566d09f02-80',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d103951735',
#          'name': 'Clothing Store',
#          'pluralName': 'Clothing Stores',
#          'primary': True,
#          'shortName': 'Apparel'}],
#        'id': '50f9a020e4b05cb566d09f02',
#        'location': {'address': '57 Rue du Temple',
#         'cc': 'FR',
#         'city': 'Paris',
#         'country': 'France',
#         'distance': 494,
#         'formattedAddress': ['57 Rue du Temple', '75004 Paris', 'France'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.86026,
#           'lng': 2.354545}],
#         'lat': 48.86026,
#         'lng': 2.354545,
#         'postalCode': '75004',
#         'state': 'Île-de-France'},
#        'name': 'Carhartt WIP',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-55855a4b498ec6f8c3b9f0c7-81',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d111941735',
#          'name': 'Japanese Restaurant',
#          'pluralName': 'Japanese Restaurants',
#          'primary': True,
#          'shortName': 'Japanese'}],
#        'id': '55855a4b498ec6f8c3b9f0c7',
#        'location': {'address': '18 rue Notre-Dame de Nazareth',
#         'cc': 'FR',
#         'city': 'Paris',
#         'country': 'France',
#         'distance': 483,
#         'formattedAddress': ['18 rue Notre-Dame de Nazareth',
#          '75003 Paris',
#          'France'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.867175899962405,
#           'lng': 2.360845491483908}],
#         'lat': 48.867175899962405,
#         'lng': 2.360845491483908,
#         'neighborhood': 'Arts et Métiers',
#         'postalCode': '75003',
#         'state': 'Île-de-France'},
#        'name': 'Bento&Go!',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5690778a498ed8487e9dc327-82',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'primary': True,
#          'shortName': 'Restaurant'}],
#        'id': '5690778a498ed8487e9dc327',
#        'location': {'address': '30 rue Notre-Dame de Nazareth',
#         'cc': 'FR',
#         'city': 'Paris',
#         'country': 'France',
#         'distance': 494,
#         'formattedAddress': ['30 rue Notre-Dame de Nazareth',
#          '75003 Paris',
#          'France'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.86730109373345,
#           'lng': 2.3595416257767576}],
#         'lat': 48.86730109373345,
#         'lng': 2.3595416257767576,
#         'postalCode': '75003',
#         'state': 'Île-de-France'},
#        'name': 'Elmer',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4bbf75e6ba9776b0b72bffc8-83',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_theater_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d137941735',
#          'name': 'Theater',
#          'pluralName': 'Theaters',
#          'primary': True,
#          'shortName': 'Theater'}],
#        'id': '4bbf75e6ba9776b0b72bffc8',
#        'location': {'address': '41 boulevard du Temple',
#         'cc': 'FR',
#         'city': 'Paris',
#         'country': 'France',
#         'distance': 460,
#         'formattedAddress': ['41 boulevard du Temple',
#          '75003 Paris',
#          'France'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.866033138912876,
#           'lng': 2.364053735005063}],
#         'lat': 48.866033138912876,
#         'lng': 2.364053735005063,
#         'postalCode': '75003',
#         'state': 'Île-de-France'},
#        'name': 'Théâtre Dejazet',
#        'photos': {'count': 0, 'groups': []}}}],
#     'name': 'recommended',
#     'type': 'Recommended Places'}],
#   'headerFullLocation': 'Enfants-Rouges, Paris',
#   'headerLocation': 'Enfants-Rouges',
#   'headerLocationGranularity': 'neighborhood',
#   'suggestedBounds': {'ne': {'lat': 48.8673723845, 'lng': 2.3668285468065267},
#    'sw': {'lat': 48.8583723755, 'lng': 2.353173425193473}},
#   'suggestedFilters': {'filters': [{'key': 'openNow', 'name': 'Open now'}],
#    'header': 'Tap to show:'},
#   'totalResults': 84}}

# %% [markdown]
# **Define the function that extracts the category of the venue.**

# %%
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %% [markdown]
# **Structure the json file into a pandas dataframe.**

# %%
# clean the json and structure it into a pandas dataframe.

venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head(20)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   after removing the cwd from sys.path.
#                                     name  ...       lng
# 0                                Mmmozza  ...  2.360591
# 1                   Chez Alain Miam Miam  ...  2.361950
# 2                  Fromagerie Jouannault  ...  2.362530
# 3                       Square du Temple  ...  2.360816
# 4              Marché des Enfants Rouges  ...  2.361996
# 5                   Chez Alain Miam Miam  ...  2.362064
# 6                                Okomusu  ...  2.360879
# 7   Le Burger Fermier des Enfants Rouges  ...  2.362073
# 8                      Hôtel Jules & Jim  ...  2.357395
# 9                                   SoMa  ...  2.362146
# 10                    Les Enfants Rouges  ...  2.361260
# 11                              Bontemps  ...  2.360725
# 12                            Chez Taeko  ...  2.362136
# 13           Bar de l'Hôtel Jules et Jim  ...  2.357393
# 14                        Paris New York  ...  2.362661
# 15                         Biglove Caffè  ...  2.363557
# 16                    Lily of the Valley  ...  2.361990
# 17                                L'Îlot  ...  2.363317
# 18                            Candelaria  ...  2.364059
# 19                       Taing Song-Heng  ...  2.356888
#
# [20 rows x 4 columns]

# %%
# Check how many venues there are in 3eme Ardt within a radius of 500 meters

print('{} venues were returned by Foursquare.'.format(nearby_venues.shape[0]))
# Out:
# 84 venues were returned by Foursquare.

# %% [markdown]
# **Create a nearby venues function for all the neighborhoods in Paris.**

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['French_Name', 
                  'Latitude', 
                  'Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %% [markdown]
# **Create a new dataframe called for the venues of Paris called paris-venues**

# %%
# Create a new dataframe called paris_venues.

paris_venues = getNearbyVenues(names=paris['French_Name'],
                                   latitudes=paris['Latitude'],
                                   longitudes=paris['Longitude']
                                  )
# Out:
# 3eme Ardt
# 19eme Ardt
# 14eme Ardt
# 10eme Ardt
# 12eme Ardt
# 16eme Ardt
# 11eme Ardt
# 2eme Ardt
# 4eme Ardt
# 17eme Ardt
# 18eme Ardt
# 1er Ardt
# 5eme Ardt
# 7eme Ardt
# 20eme Ardt
# 8eme Ardt
# 9eme Ardt
# 13eme Ardt
# 15eme Ardt
# 6eme Ardt

# %%
print(paris_venues.shape)
paris_venues.head(250)
# Out:
# (1238, 7)
#     French_Name   Latitude  ...  Venue Longitude     Venue Category
# 0     3eme Ardt  48.862872  ...         2.360591     Sandwich Place
# 1     3eme Ardt  48.862872  ...         2.361950     Sandwich Place
# 2     3eme Ardt  48.862872  ...         2.362530        Cheese Shop
# 3     3eme Ardt  48.862872  ...         2.360816               Park
# 4     3eme Ardt  48.862872  ...         2.361996     Farmers Market
# ..          ...        ...  ...              ...                ...
# 245  10eme Ardt  48.876130  ...         2.356484  Indian Restaurant
# 246  10eme Ardt  48.876130  ...         2.364304     Sandwich Place
# 247  10eme Ardt  48.876130  ...         2.359683             Bistro
# 248  10eme Ardt  48.876130  ...         2.354361              Hotel
# 249  10eme Ardt  48.876130  ...         2.357819              Hotel
#
# [250 rows x 7 columns]

# %% [markdown]
# **Check how many venues were returned for each neighborhood.**

# %%
paris_venues.groupby('French_Name').count()
# Out:
#              Latitude  Longitude  ...  Venue Longitude  Venue Category
# French_Name                       ...
# 10eme Ardt        100        100  ...              100             100
# 11eme Ardt         66         66  ...               66              66
# 12eme Ardt          4          4  ...                4               4
# 13eme Ardt         59         59  ...               59              59
# 14eme Ardt         25         25  ...               25              25
# 15eme Ardt         62         62  ...               62              62
# 16eme Ardt         12         12  ...               12              12
# 17eme Ardt         61         61  ...               61              61
# 18eme Ardt         41         41  ...               41              41
# 19eme Ardt         41         41  ...               41              41
# 1er Ardt           70         70  ...               70              70
# 20eme Ardt         51         51  ...               51              51
# 2eme Ardt         100        100  ...              100             100
# 3eme Ardt          84         84  ...               84              84
# 4eme Ardt         100        100  ...              100             100
# 5eme Ardt          90         90  ...               90              90
# 6eme Ardt          39         39  ...               39              39
# 7eme Ardt         100        100  ...              100             100
# 8eme Ardt          33         33  ...               33              33
# 9eme Ardt         100        100  ...              100             100
#
# [20 rows x 6 columns]

# %% [markdown]
# **Calculate how many unique venue categories there are**

# %%
print('There are {} unique venue categories.'.format(len(paris_venues['Venue Category'].unique())))
# Out:
# There are 194 unique venue categories.

# %% [markdown]
# **Analyze each of the Neighborhoods**

# %%
# Analyze each of the Neighborhoods from the results

# one hot encoding
paris_onehot = pd.get_dummies(paris_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
paris_onehot['Neighborhood'] = paris_venues['French_Name'] 

# move neighborhood column to the first column
fixed_columns = [paris_onehot.columns[-1]] + list(paris_onehot.columns[:-1])
paris_onehot = paris_onehot[fixed_columns]

paris_onehot
# Out:
#      Neighborhood  Afghan Restaurant  ...  Zoo  Zoo Exhibit
# 0       3eme Ardt                  0  ...    0            0
# 1       3eme Ardt                  0  ...    0            0
# 2       3eme Ardt                  0  ...    0            0
# 3       3eme Ardt                  0  ...    0            0
# 4       3eme Ardt                  0  ...    0            0
# ...           ...                ...  ...  ...          ...
# 1233    6eme Ardt                  0  ...    0            0
# 1234    6eme Ardt                  0  ...    0            0
# 1235    6eme Ardt                  0  ...    0            0
# 1236    6eme Ardt                  0  ...    0            0
# 1237    6eme Ardt                  0  ...    0            0
#
# [1238 rows x 195 columns]

# %%
# The shape of the dataframe
paris_onehot.shape
# Out:
# (1238, 195)

# %% [markdown]
# **Group rows by neighborhood and take the mean of the frequency of occurrence of each category.**

# %%
paris_grouped = paris_onehot.groupby('Neighborhood').mean().reset_index()
paris_grouped
# Out:
#    Neighborhood  Afghan Restaurant  ...   Zoo  Zoo Exhibit
# 0    10eme Ardt           0.000000  ...  0.00         0.00
# 1    11eme Ardt           0.015152  ...  0.00         0.00
# 2    12eme Ardt           0.000000  ...  0.25         0.25
# 3    13eme Ardt           0.000000  ...  0.00         0.00
# 4    14eme Ardt           0.000000  ...  0.00         0.00
# 5    15eme Ardt           0.000000  ...  0.00         0.00
# 6    16eme Ardt           0.000000  ...  0.00         0.00
# 7    17eme Ardt           0.000000  ...  0.00         0.00
# 8    18eme Ardt           0.000000  ...  0.00         0.00
# 9    19eme Ardt           0.000000  ...  0.00         0.00
# 10     1er Ardt           0.000000  ...  0.00         0.00
# 11   20eme Ardt           0.000000  ...  0.00         0.00
# 12    2eme Ardt           0.000000  ...  0.00         0.00
# 13    3eme Ardt           0.000000  ...  0.00         0.00
# 14    4eme Ardt           0.000000  ...  0.00         0.00
# 15    5eme Ardt           0.000000  ...  0.00         0.00
# 16    6eme Ardt           0.000000  ...  0.00         0.00
# 17    7eme Ardt           0.000000  ...  0.00         0.00
# 18    8eme Ardt           0.000000  ...  0.00         0.00
# 19    9eme Ardt           0.000000  ...  0.00         0.00
#
# [20 rows x 195 columns]

# %%
# The shape of the grouped data
paris_grouped.shape
# Out:
# (20, 195)

# %% [markdown]
# **Print each neighborhood with top 10 most common venues**

# %%
num_top_venues = 10

for hood in paris_grouped['Neighborhood']:
    print("----"+hood+"----")
    temp = paris_grouped[paris_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----10eme Ardt----
#                  venue  freq
# 0    French Restaurant  0.13
# 1          Coffee Shop  0.05
# 2               Bistro  0.05
# 3                Hotel  0.05
# 4                 Café  0.04
# 5    Indian Restaurant  0.04
# 6  Japanese Restaurant  0.03
# 7          Pizza Place  0.03
# 8           Restaurant  0.02
# 9         Cocktail Bar  0.02
#
#
# ----11eme Ardt----
#                venue  freq
# 0  French Restaurant  0.12
# 1         Restaurant  0.06
# 2        Pastry Shop  0.05
# 3        Supermarket  0.05
# 4           Wine Bar  0.05
# 5            Theater  0.03
# 6        Pizza Place  0.03
# 7                Bar  0.03
# 8             Bakery  0.03
# 9               Café  0.03
#
#
# ----12eme Ardt----
#                         venue  freq
# 0                 Zoo Exhibit  0.25
# 1                         Zoo  0.25
# 2                 Supermarket  0.25
# 3         Monument / Landmark  0.25
# 4      Okonomiyaki Restaurant  0.00
# 5  Modern European Restaurant  0.00
# 6         Moroccan Restaurant  0.00
# 7               Movie Theater  0.00
# 8                      Museum  0.00
# 9                 Music Store  0.00
#
#
# ----13eme Ardt----
#                     venue  freq
# 0   Vietnamese Restaurant  0.22
# 1        Asian Restaurant  0.19
# 2      Chinese Restaurant  0.08
# 3         Thai Restaurant  0.08
# 4       French Restaurant  0.07
# 5               Juice Bar  0.05
# 6          Cosmetics Shop  0.02
# 7                   Plaza  0.02
# 8  Furniture / Home Store  0.02
# 9                 Butcher  0.02
#
#
# ----14eme Ardt----
#                   venue  freq
# 0     French Restaurant  0.40
# 1           Supermarket  0.08
# 2                 Hotel  0.08
# 3                Bakery  0.04
# 4     Food & Drink Shop  0.04
# 5             Brasserie  0.04
# 6      Sushi Restaurant  0.04
# 7  Fast Food Restaurant  0.04
# 8                Bistro  0.04
# 9              Tea Room  0.04
#
#
# ----15eme Ardt----
#                  venue  freq
# 0                Hotel  0.11
# 1   Italian Restaurant  0.11
# 2    French Restaurant  0.08
# 3          Coffee Shop  0.05
# 4               Bakery  0.03
# 5    Indian Restaurant  0.03
# 6  Lebanese Restaurant  0.03
# 7      Thai Restaurant  0.03
# 8                 Park  0.03
# 9  Japanese Restaurant  0.03
#
#
# ----16eme Ardt----
#                venue  freq
# 0               Park  0.17
# 1               Lake  0.17
# 2              Plaza  0.17
# 3  French Restaurant  0.08
# 4        Bus Station  0.08
# 5      Boat or Ferry  0.08
# 6           Bus Stop  0.08
# 7               Pool  0.08
# 8         Art Museum  0.08
# 9       Perfume Shop  0.00
#
#
# ----17eme Ardt----
#                  venue  freq
# 0    French Restaurant  0.18
# 1                Hotel  0.18
# 2  Japanese Restaurant  0.08
# 3   Italian Restaurant  0.08
# 4               Bakery  0.07
# 5                Plaza  0.07
# 6               Bistro  0.05
# 7           Restaurant  0.03
# 8                 Café  0.03
# 9          Pizza Place  0.02
#
#
# ----18eme Ardt----
#                        venue  freq
# 0                        Bar  0.15
# 1          French Restaurant  0.12
# 2                 Restaurant  0.05
# 3                Coffee Shop  0.05
# 4                      Hotel  0.05
# 5          Convenience Store  0.05
# 6                Supermarket  0.02
# 7          Health Food Store  0.02
# 8       Gym / Fitness Center  0.02
# 9  Middle Eastern Restaurant  0.02
#
#
# ----19eme Ardt----
#                  venue  freq
# 0    French Restaurant  0.10
# 1                  Bar  0.10
# 2   Seafood Restaurant  0.05
# 3               Bistro  0.05
# 4             Beer Bar  0.05
# 5                Hotel  0.05
# 6          Supermarket  0.05
# 7  Japanese Restaurant  0.05
# 8       Sandwich Place  0.02
# 9         Concert Hall  0.02
#
#
# ----1er Ardt----
#                  venue  freq
# 0    French Restaurant  0.11
# 1  Japanese Restaurant  0.09
# 2                Plaza  0.09
# 3   Italian Restaurant  0.07
# 4                Hotel  0.07
# 5           Art Museum  0.04
# 6          Cheese Shop  0.03
# 7          Candy Store  0.03
# 8      Thai Restaurant  0.03
# 9          Coffee Shop  0.03
#
#
# ----20eme Ardt----
#                  venue  freq
# 0   Italian Restaurant  0.10
# 1  Japanese Restaurant  0.08
# 2               Bakery  0.08
# 3               Bistro  0.06
# 4                Plaza  0.06
# 5    French Restaurant  0.06
# 6                  Bar  0.06
# 7                 Café  0.04
# 8                Hotel  0.04
# 9               Lounge  0.02
#
#
# ----2eme Ardt----
#                 venue  freq
# 0   French Restaurant  0.13
# 1            Wine Bar  0.06
# 2        Cocktail Bar  0.06
# 3               Hotel  0.05
# 4              Bakery  0.04
# 5            Creperie  0.03
# 6              Bistro  0.03
# 7  Italian Restaurant  0.03
# 8     Thai Restaurant  0.02
# 9        Concert Hall  0.02
#
#
# ----3eme Ardt----
#                  venue  freq
# 0    French Restaurant  0.10
# 1  Japanese Restaurant  0.06
# 2         Gourmet Shop  0.05
# 3          Art Gallery  0.05
# 4         Burger Joint  0.04
# 5               Bakery  0.04
# 6          Coffee Shop  0.04
# 7         Cocktail Bar  0.04
# 8       Clothing Store  0.04
# 9       Sandwich Place  0.04
#
#
# ----4eme Ardt----
#                 venue  freq
# 0   French Restaurant  0.15
# 1      Ice Cream Shop  0.05
# 2               Hotel  0.04
# 3      Clothing Store  0.03
# 4            Wine Bar  0.03
# 5              Garden  0.03
# 6            Tea Room  0.03
# 7  Italian Restaurant  0.03
# 8    Pedestrian Plaza  0.03
# 9         Coffee Shop  0.02
#
#
# ----5eme Ardt----
#                 venue  freq
# 0   French Restaurant  0.12
# 1  Italian Restaurant  0.07
# 2               Hotel  0.06
# 3      Science Museum  0.04
# 4               Plaza  0.04
# 5              Bakery  0.04
# 6                Café  0.03
# 7         Coffee Shop  0.03
# 8                 Pub  0.03
# 9    Greek Restaurant  0.02
#
#
# ----6eme Ardt----
#                 venue  freq
# 0   French Restaurant  0.08
# 1            Wine Bar  0.05
# 2            Fountain  0.05
# 3        Dessert Shop  0.05
# 4               Plaza  0.05
# 5              Bistro  0.05
# 6  Italian Restaurant  0.05
# 7          Art Museum  0.03
# 8      Chocolate Shop  0.03
# 9       Shopping Mall  0.03
#
#
# ----7eme Ardt----
#                 venue  freq
# 0               Hotel  0.20
# 1   French Restaurant  0.17
# 2                Café  0.06
# 3  Italian Restaurant  0.06
# 4               Plaza  0.04
# 5        Cocktail Bar  0.03
# 6      History Museum  0.03
# 7         Coffee Shop  0.03
# 8           Irish Pub  0.02
# 9              Garden  0.02
#
#
# ----8eme Ardt----
#                         venue  freq
# 0           French Restaurant  0.21
# 1                       Hotel  0.15
# 2         Corsican Restaurant  0.06
# 3                 Art Gallery  0.06
# 4                         Spa  0.06
# 5                     Theater  0.03
# 6                   Hotel Bar  0.03
# 7    Mediterranean Restaurant  0.03
# 8      Furniture / Home Store  0.03
# 9  Modern European Restaurant  0.03
#
#
# ----9eme Ardt----
#                  venue  freq
# 0    French Restaurant  0.17
# 1                Hotel  0.08
# 2         Cocktail Bar  0.05
# 3               Bistro  0.04
# 4               Bakery  0.04
# 5                 Café  0.03
# 6               Lounge  0.03
# 7             Wine Bar  0.03
# 8  Japanese Restaurant  0.03
# 9   Italian Restaurant  0.02

# %% [markdown]
# **Put that data into a pandas dataframe and sort the venues in descending order**

# %%
# First sort the venues in descending order.

def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %% [markdown]
# **The top 10 venue categories for each neighborhood**

# %%
# create the new dataframe and display the top 10 venues for each neighborhood

num_top_venues = 10
indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))
        
# create a new dataframe
paris_venues_sorted = pd.DataFrame(columns=columns)
paris_venues_sorted['Neighborhood'] = paris_grouped['Neighborhood']

for ind in np.arange(paris_grouped.shape[0]):
    paris_venues_sorted.iloc[ind, 1:] = return_most_common_venues(paris_grouped.iloc[ind, :], num_top_venues)

paris_venues_sorted.head(20)
# Out:
#    Neighborhood  ...     10th Most Common Venue
# 0    10eme Ardt  ...             Breakfast Spot
# 1    11eme Ardt  ...               Cocktail Bar
# 2    12eme Ardt  ...         African Restaurant
# 3    13eme Ardt  ...             Sandwich Place
# 4    14eme Ardt  ...                     Bistro
# 5    15eme Ardt  ...            Thai Restaurant
# 6    16eme Ardt  ...               Dessert Shop
# 7    17eme Ardt  ...   Mediterranean Restaurant
# 8    18eme Ardt  ...  Middle Eastern Restaurant
# 9    19eme Ardt  ...                 Restaurant
# 10     1er Ardt  ...                    Theater
# 11   20eme Ardt  ...           Sushi Restaurant
# 12    2eme Ardt  ...                Coffee Shop
# 13    3eme Ardt  ...                     Bakery
# 14    4eme Ardt  ...                    Gay Bar
# 15    5eme Ardt  ...                Pizza Place
# 16    6eme Ardt  ...             Chocolate Shop
# 17    7eme Ardt  ...                Cheese Shop
# 18    8eme Ardt  ...                     Resort
# 19    9eme Ardt  ...         Turkish Restaurant
#
# [20 rows x 11 columns]

# %%
# The shape of the sorted data
paris_venues_sorted.shape
# Out:
# (20, 11)

# %% [markdown]
# **Let's look at their frequency of occurance of 'French Restaurants', 'Cafés' and 'Wine Bars' in all of Paris' neighborhoods**

# %%
# Categorical plot
# Explore a plot of this data (a violin plot is used which is a density estimation of the underlying distribution).
# The top 3 venue types as specified by the client for each neighborhood are used for the plotting.

import seaborn as sns

fig = plt.figure(figsize=(50,25))
sns.set(font_scale=1.1)

ax = plt.subplot(3,1,1)
sns.violinplot(x="Neighborhood", y="French Restaurant", data=paris_onehot, cut=0);
plt.xlabel("")

ax = plt.subplot(3,1,2)
sns.violinplot(x="Neighborhood", y="Café", data=paris_onehot, cut=0);
plt.xlabel("")

plt.subplot(3,1,3)
sns.violinplot(x="Neighborhood", y="Wine Bar", data=paris_onehot, cut=0);

ax.text(-1.0, 3.1, 'Frequency distribution for the top 3 venue categories for each neighborhood (click to enlage)', fontsize=60)
plt.savefig ("Distribution_Frequency_Venues_3_categories.png", dpi=240)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# **Let's look at the venue category - 'Clothing Store'**

# %%
fig = plt.figure(figsize=(50,15))
sns.set(font_scale=1.1)

ax = plt.subplot(1,1,1)
sns.violinplot(x="Neighborhood", y="Clothing Store", data=paris_onehot, cut=0);
plt.xlabel("")

ax.text(1.0, 1.1, 'Frequency of Clothing stores for each neighborhood', fontsize=60)
plt.savefig ("Distribution_Frequency_Clothing_Venues.png", dpi=240)

# %% [markdown]
# **Let's add this to the analysis with the 3 other formerly specified categories.**

# %%
fig = plt.figure(figsize=(50,25))
sns.set(font_scale=1.1)

ax = plt.subplot(4,1,1)
sns.violinplot(x="Neighborhood", y="French Restaurant", data=paris_onehot, cut=0);
plt.xlabel("")

ax = plt.subplot(4,1,2)
sns.violinplot(x="Neighborhood", y="Café", data=paris_onehot, cut=0);
plt.xlabel("")

plt.subplot(4,1,3)
sns.violinplot(x="Neighborhood", y="Wine Bar", data=paris_onehot, cut=0);

plt.subplot(4,1,4)
sns.violinplot(x="Neighborhood", y="Clothing Store", data=paris_onehot, cut=0);

ax.text(-1.0, 3.1, 'Frequency distribution for the top 3 venue categories for each neighborhood (includes clothing)', fontsize=60)
plt.savefig ("Distribution_Frequency_Venues_3_categories_clothing.png", dpi=240)
plt.show()

# %% [markdown]
# The prospective neighborhoods for our new store locations, where all four criteria were met, are:
# - 3eme Ardt : Arrondissement 3, Temple
# - 4eme Ardt : Arrondissement 4, Hotel-de-Ville
# - 6eme Ardt : Arrondissement 6, Luxembourg,

# %% [markdown]
# **Download geo data about those districts and put that into a new dataframe**

# %%
# The csv of the 3 chosen prospective neighborhoods was uploaded to GitHub for access and reference

chosen_districts = pd.read_csv('https://raw.githubusercontent.com/turtlefreezer/Capstone/master/Chosen.csv')
chosen_districts
# Out:
#    Arrondissement_Num    Neighborhood French_Name   Latitude  Longitude
# 0                   3          Temple   3eme Ardt  48.862872   2.360001
# 1                   4  Hotel-de-Ville   4eme Ardt  48.854341   2.357630
# 2                   6      Luxembourg   6eme Ardt  48.849130   2.332898

# %% [markdown]
# **Let's visualise them on a map of Paris.**

# %%
# Create a folium map of Paris with the 3 neighborhoods superimposed on the map
map_chosen_districts = folium.Map(location=[latitude, longitude], zoom_start=13)

# add markers to map
for lat, lng, label in zip(chosen_districts['Latitude'], chosen_districts['Longitude'], chosen_districts['French_Name']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=45,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.2,
        parse_html=False).add_to(map_chosen_districts)  
    
map_chosen_districts
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# **Now, an even closer look on Central Paris with the identified districts.**

# %%
map_chosen_districts = folium.Map(location=[latitude, longitude], zoom_start=15)

# add markers to map
for lat, lng, label in zip(chosen_districts['Latitude'], chosen_districts['Longitude'], chosen_districts['French_Name']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=130,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.2,
        parse_html=False).add_to(map_chosen_districts)  
    
map_chosen_districts
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
